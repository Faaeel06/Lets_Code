# %% [markdown]
# #### Instalações

# %%
class installation_libs():

    def package_installing():   
        # %pip install pip --upgrade
        # %pip install pip --update
        # %pip install matplotlib
        # %pip install pandas
        # %pip install sklearn
        # %pip install seaborn
        # %pip install hyperopt
        # %pip install imblearn
        # %pip install pytesseract
        # %pip install scikit-image
        # %pip install opencv-python
        # %pip install tensorflow
        # %pip install tensorflow-cpu
        # %pip install librosa
        # %pip install nltk
        # %pip install emoji
        # %pip install unidecode
        # %pip install svgling
        # %pip install spacy
        # %pip install lightgbm
        # %pip install gensim
        # %pip install unidecode
        # %pip install mlxtend
        # %pip install psycopg2

    
    def force_installing():
        # !pip install pip --upgrade
        # !pip install pip --update
        # !pip install matplotlib
        # !pip install pandas
        # !pip install sklearn
        # !pip install seaborn
        # !pip install hyperopt
        # !pip install imblearn
        # !pip install pytesseract
        # !pip install scikit-image
        # !pip install opencv-python
        # !pip install tensorflow
        # !pip install tensorflow-cpu
        # !pip install librosa
        # !pip install nltk
        # !pip install emoji
        # !pip install unidecode
        # !pip install svgling
        # !pip install spacy
        # !pip install lightgbm
        # !pip install gensim
        # !pip install unidecode
        # !pip install mlxtend
        # !pip install psycopg2

    
    def download_extension():
        # !python3 -m spacy download "pt_core_news_sm"

# %% [markdown]
# #### Desinstalações

# %%
class uninstallation_libs():
    def package_uninstalling():
        # %pip uninstall tensorflow -y
        # %pip uninstall flatbuffers -y
        # %pip uninstall keras -y
        # %pip uninstall keras-nightly -y
        # %pip uninstall Keras-Preprocessing -y
        # %pip uninstall tensorboard -y
        # %pip uninstall tensorboard-data-server -y
        # %pip uninstall tensorboard-plugin-wit -y
        # %pip uninstall tensorflow-estimator -y
        # %pip uninstall tensorflow-io-gcs-filesystem -y
        # %pip uninstall tensorflow-gpu -y
        # %pip uninstall nltk -y
        # %pip uninstall emoji -y
        # %pip uninstall unidecode -y
        # %pip uninstall svgling -y
        # %pip uninstall tensorboard -y
        # %pip uninstall tensorboard-data-server -y
        # %pip uninstall tensorboard-plugin-wit -y
        # %pip uninstall tensorflow-estimator -y
        # %pip uninstall tensorflow-io-gcs-filesystem -y
        # %pip uninstall tensorflow-gpu -y
        # %pip uninstall tensorflow -y
        # %pip uninstall tensorflow-cpu -y
        # %pip uninstall mlxtend -y
        # %pip uninstall psycopg2 -y
    
    def force_uninstalling():
        # !pip uninstall matplotlib -y
        # !pip uninstall pandas -y
        # !pip uninstall sklearn -y
        # !pip uninstall seaborn -y
        # !pip uninstall hyperopt -y
        # !pip uninstall imblearn -y
        # !pip uninstall pytesseract -y
        # !pip uninstall scikit-image -y
        # !pip uninstall opencv-python -y
        # !pip uninstall tensorflow -y
        # !pip uninstall librosa -y
        # !pip uninstall nltk -y
        # !pip uninstall emoji -y
        # !pip uninstall unidecode -y
        # !pip uninstall svgling -y
        # !pip uninstall tensorboard -y
        # !pip uninstall tensorboard-data-server -y
        # !pip uninstall tensorboard-plugin-wit -y
        # !pip uninstall tensorflow-estimator -y
        # !pip uninstall tensorflow-io-gcs-filesystem -y
        # !pip uninstall tensorflow-gpu -y
        # !pip uninstall tensorflow -y
        # !pip uninstall tensorflow-cpu -y
        # !pip uninstall mlxtend -y
        # !pip uninstall psycopg2 -y

# %%
uninstallation_libs.force_uninstalling()
uninstallation_libs.package_uninstalling()
installation_libs.force_installing()
installation_libs.package_installing()
# Out:
# Found existing installation: matplotlib 3.6.0
# Uninstalling matplotlib-3.6.0:
#   Successfully uninstalled matplotlib-3.6.0
# Found existing installation: pandas 1.5.0
# Uninstalling pandas-1.5.0:
#   Successfully uninstalled pandas-1.5.0
# Found existing installation: sklearn 0.0
# Uninstalling sklearn-0.0:
#   Successfully uninstalled sklearn-0.0
# Found existing installation: seaborn 0.12.0
# Uninstalling seaborn-0.12.0:
#   Successfully uninstalled seaborn-0.12.0
# Found existing installation: hyperopt 0.2.7
# Uninstalling hyperopt-0.2.7:
#   Successfully uninstalled hyperopt-0.2.7
# Found existing installation: imblearn 0.0
# Uninstalling imblearn-0.0:
#   Successfully uninstalled imblearn-0.0
# Found existing installation: pytesseract 0.3.10
# Uninstalling pytesseract-0.3.10:
#   Successfully uninstalled pytesseract-0.3.10
# Found existing installation: scikit-image 0.19.3
# Uninstalling scikit-image-0.19.3:
#   Successfully uninstalled scikit-image-0.19.3
# ...

# %%
installation_libs.package_installing()
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 592.1 kB/s eta 0:00:0000:0100:01
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 22.2.2
#     Uninstalling pip-22.2.2:
#       Successfully uninstalled pip-22.2.2
# ...
# Note: you may need to restart the kernel to use updated packages.
#
# Usage:
#   /usr/bin/python3 -m pip install [options] <requirement specifier> [package-index-options] ...
#   /usr/bin/python3 -m pip install [options] -r <requirements file> [package-index-options] ...
#   /usr/bin/python3 -m pip install [options] [-e] <vcs project url> ...
#   /usr/bin/python3 -m pip install [options] [-e] <local project path> ...
#   /usr/bin/python3 -m pip install [options] <archive url/path> ...
#
# no such option: --update
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# ...
