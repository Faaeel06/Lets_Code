# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd
avocado = pd.read_csv('avocado.csv')
avocado_tp = pd.read_csv('avocado_type.csv')
avocado_fim = avocado.join(avocado_tp)
avocado_fim.to_csv('avocado_fim.csv')
avocado_fim
# Out:
#              Date  AveragePrice  Total Volume  year            region  \
# 0      2015-12-27          1.33      64236.62  2015            Albany
# 1      2015-12-20          1.35      54876.98  2015            Albany
# 2      2015-12-13          0.93     118220.22  2015            Albany
# 3      2015-12-06          1.08      78992.15  2015            Albany
# 4      2015-11-29          1.28      51039.60  2015            Albany
# ...           ...           ...           ...   ...               ...
# 18244  2018-02-04          1.63      17074.83  2018  WestTexNewMexico
# 18245  2018-01-28          1.71      13888.04  2018  WestTexNewMexico
# 18246  2018-01-21          1.87      13766.76  2018  WestTexNewMexico
# 18247  2018-01-14          1.93      16205.22  2018  WestTexNewMexico
# 18248  2018-01-07          1.62      17489.58  2018  WestTexNewMexico
#
#                type
# 0      conventional
# 1      conventional
# 2      conventional
# 3      conventional
# ...

# %%
new_avocado = pd.read_csv('avocado_fim.csv')
new_avocado['type'].value_counts()
new_avocado['region'].value_counts()
new_avocado.columns = new_avocado.columns.str.lower()
new_avocado.drop('year', inplace=True, axis=1)
new_avocado
# Out:
#        unnamed: 0        date  averageprice  total volume            region  \
# 0               0  2015-12-27          1.33      64236.62            Albany
# 1               1  2015-12-20          1.35      54876.98            Albany
# 2               2  2015-12-13          0.93     118220.22            Albany
# 3               3  2015-12-06          1.08      78992.15            Albany
# 4               4  2015-11-29          1.28      51039.60            Albany
# ...           ...         ...           ...           ...               ...
# 18244       18244  2018-02-04          1.63      17074.83  WestTexNewMexico
# 18245       18245  2018-01-28          1.71      13888.04  WestTexNewMexico
# 18246       18246  2018-01-21          1.87      13766.76  WestTexNewMexico
# 18247       18247  2018-01-14          1.93      16205.22  WestTexNewMexico
# 18248       18248  2018-01-07          1.62      17489.58  WestTexNewMexico
#
#                type
# 0      conventional
# ...

# %%
avocado_conventional = np.where((new_avocado['type'] == 'conventional'))
avocado_organic = np.where((new_avocado['type'] == 'organic'))
print(f'Volume total do tipo Convencional: {new_avocado.iloc[avocado_conventional]["total volume"].sum()}')
print(f'Volume total do tipo Orgânico: {new_avocado.iloc[avocado_organic]["total volume"].sum()}')
print(f'Preço Médio do tipo Convencional: {new_avocado.iloc[avocado_conventional]["averageprice"].mean()}')
print(f'Preço Médio do tipo Orgânico: {new_avocado.iloc[avocado_organic]["averageprice"].mean()}')
print('=-=' * 100)
print(f'Análise do tipo Convencional: {new_avocado.iloc[avocado_conventional].describe()}')
print(f'Análise do tipo Orgânico: {new_avocado.iloc[avocado_organic].describe()}')
# Out:
# Volume total do tipo Convencional: 15087220911.31
# Volume total do tipo Orgânico: 436181682.0899999
# Preço Médio do tipo Convencional: 1.1580396668858208
# Preço Médio do tipo Orgânico: 1.6539986846432095
# =-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-=
# Análise do tipo Convencional:         unnamed: 0  averageprice  total volume
# count  9126.000000   9126.000000  9.126000e+03
# mean   4562.500000      1.158040  1.653213e+06
# std    2634.593612      0.263041  4.747892e+06
# min       0.000000      0.460000  3.369968e+04
# 25%    2281.250000      0.980000  1.989086e+05
# 50%    4562.500000      1.130000  4.083255e+05
# 75%    6843.750000      1.320000  1.030992e+06
# max    9125.000000      2.220000  6.250565e+07
# ...

# %%
avocado_conventional
# Out:
# (array([   0,    1,    2, ..., 9123, 9124, 9125]),)

# %%
print(f'Volume total do tipo Convencional: {new_avocado.iloc[avocado_conventional]["total volume"].sum()}')
print(f'Volume total do tipo Orgânico: {new_avocado.iloc[avocado_organic]["total volume"].sum()}')
print(f'Preço Médio do tipo Convencional: {new_avocado.iloc[avocado_conventional]["averageprice"].mean()}')
print(f'Preço Médio do tipo Orgânico: {new_avocado.iloc[avocado_organic]["averageprice"].mean()}')
print('=-=' * 100)
print(f'\n\nAnálise do tipo Convencional: {new_avocado.iloc[avocado_conventional].describe()}')
print(f'\n\nAnálise do tipo Orgânico: {new_avocado.iloc[avocado_organic].describe()}')
# Out:
# Volume total do tipo Convencional: 15087220911.31
# Volume total do tipo Orgânico: 436181682.0899999
# Preço Médio do tipo Convencional: 1.1580396668858208
# Preço Médio do tipo Orgânico: 1.6539986846432095
# =-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-=
#
#
# Análise do tipo Convencional:         unnamed: 0  averageprice  total volume
# count  9126.000000   9126.000000  9.126000e+03
# mean   4562.500000      1.158040  1.653213e+06
# std    2634.593612      0.263041  4.747892e+06
# min       0.000000      0.460000  3.369968e+04
# 25%    2281.250000      0.980000  1.989086e+05
# 50%    4562.500000      1.130000  4.083255e+05
# 75%    6843.750000      1.320000  1.030992e+06
# max    9125.000000      2.220000  6.250565e+07
#
#
# ...

# %%
Gplay = pd.read_csv('googleplaystore.csv')
display(Gplay)
Gplay.info()
new_Gplay = Gplay.drop_duplicates().dropna()
new_Gplay.info()
new_Gplay
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
aluguel = pd.read_csv('houses_to_rent.csv')
display(aluguel.head(10), aluguel.tail(10), aluguel.info())
display(aluguel.duplicated().sum())
display(aluguel.isna().sum())
display(aluguel.isnull().sum())
aluguel = aluguel.drop_duplicates()
display(aluguel)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10692 entries, 0 to 10691
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   city                 10692 non-null  object
#  1   area                 10692 non-null  int64
#  2   rooms                10692 non-null  int64
#  3   bathroom             10692 non-null  int64
#  4   parking spaces       10692 non-null  int64
#  5   floor                10692 non-null  object
#  6   animal               10692 non-null  object
#  7   furniture            10692 non-null  object
#  8   hoa (R$)             10692 non-null  int64
#  9   rent amount (R$)     10692 non-null  int64
#  10  property tax (R$)    10692 non-null  int64
#  11  fire insurance (R$)  10692 non-null  int64
#  12  total (R$)           10692 non-null  int64
# dtypes: int64(9), object(4)
# memory usage: 1.1+ MB
# ...

# %%
import numpy as np
from cmath import exp, sin
import matplotlib.pyplot as plt

x = np.random.randint(-10, 10, size=200)

y1 = []
y2 = []
for i in range(len(x)):
    x_n = x[i]
    if x_n == 0:
        y1.append(0)
        y2.append(0)
    else:
        y1.append(sin(x_n)/x_n)

        y2.append(1/(1-exp(-x_n)))

plt.plot(x, y1)
plt.show()

plt.plot(x, y2)
plt.show()
# Out:
# /home/Faaeel06/.local/lib/python3.9/site-packages/matplotlib/cbook/__init__.py:1369: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
cal_avocado = pd.read_csv('avocado.csv')
cal_avocado
# Out:
#              Date  AveragePrice  Total Volume  year            region
# 0      2015-12-27          1.33      64236.62  2015            Albany
# 1      2015-12-20          1.35      54876.98  2015            Albany
# 2      2015-12-13          0.93     118220.22  2015            Albany
# 3      2015-12-06          1.08      78992.15  2015            Albany
# 4      2015-11-29          1.28      51039.60  2015            Albany
# ...           ...           ...           ...   ...               ...
# 18244  2018-02-04          1.63      17074.83  2018  WestTexNewMexico
# 18245  2018-01-28          1.71      13888.04  2018  WestTexNewMexico
# 18246  2018-01-21          1.87      13766.76  2018  WestTexNewMexico
# 18247  2018-01-14          1.93      16205.22  2018  WestTexNewMexico
# 18248  2018-01-07          1.62      17489.58  2018  WestTexNewMexico
#
# [18249 rows x 5 columns]

# %%
cholera = pd.read_csv('cholera-dataset.csv')

# %%
plt.bar(cholera, x='Number of reported cases of cholera')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/Faaeel06/Documentos/GitHub/Lets_Code/Data Science Degree/Modulo_04/Dúvidas exercício/Exercicio12.ipynb Cell 14 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/Faaeel06/Documentos/GitHub/Lets_Code/Data%20Science%20Degree/Modulo_04/D%C3%BAvidas%20exerc%C3%ADcio/Exercicio12.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> plt.bar(cholera, x='Number of reported cases of cholera')
#       <a href='vscode-notebook-cell:/home/Faaeel06/Documentos/GitHub/Lets_Code/Data%20Science%20Degree/Modulo_04/D%C3%BAvidas%20exerc%C3%ADcio/Exercicio12.ipynb#X16sZmlsZQ%3D%3D?line=1'>2</a> plt.show()
#
# TypeError: bar() got multiple values for argument 'x'
